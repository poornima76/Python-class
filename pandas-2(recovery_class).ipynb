# %% [markdown]
# # General Properties or Nature of DataFrame

# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame(np.array([1,2,3,4,5]))
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd.DataFrame(np.array([1,2,3,4,5]), index=list('abcde'))
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
pd.DataFrame(np.array([1,2,3,4,5]), index=list('abcde'),columns=list('j'))
# Out:
#    j
# a  1
# b  2
# c  3
# d  4
# e  5

# %% [markdown]
# if dataFrame is made using a dictionary, then the key becomes the column name

# %%
d = {'first': [1,2,3,4,5], 'second':[8,9,10,11,12]}

# %%
pd.DataFrame(d)
# Out:
#    first  second
# 0      1       8
# 1      2       9
# 2      3      10
# 3      4      11
# 4      5      12

# %%
pd.DataFrame(d, index=list('abcde'))
# Out:
#    first  second
# a      1       8
# b      2       9
# c      3      10
# d      4      11
# e      5      12

# %%
df = pd.read_csv('titanic_test.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## to read only  a certain number of columns

# %%
df = pd.read_csv('titanic_test.csv', usecols=['Name','Sex'])

# %%
df
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# f = pd.read_json()# some link)

# %%
f.to_csv('some_name.csv')

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (891, 2)

# %%
df.size
# Out:
# 1782

# %%
df.dtypes
# Out:
# Name    object
# Sex     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Sex'], dtype='object')

# %%
len(df.columns)
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# print a concise summary of DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    891 non-null    object
#  1   Sex     891 non-null    object
# dtypes: object(2)
# memory usage: 14.0+ KB

# %%
df.describe()
# Out:
#                            Name   Sex
# count                       891   891
# unique                      891     2
# top     Braund, Mr. Owen Harris  male
# freq                          1   577

# %% [markdown]
# ## Columns selection

# %%
df1 = pd.read_csv('titanic_test.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['PassengerId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# ## Selecting multiple columns

# %%
df1[['PassengerId','Sex']]
# Out:
#      PassengerId     Sex
# 0              1    male
# 1              2  female
# 2              3  female
# 3              4  female
# 4              5    male
# ..           ...     ...
# 886          887    male
# 887          888  female
# 888          889  female
# 889          890    male
# 890          891    male
#
# [891 rows x 2 columns]

# %% [markdown]
# ## selecting one column in 2D

# %%
df1[['PassengerId']]
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]

# %% [markdown]
# ## Change column values

# %%
df1.PassengerId = 100

# %% [markdown]
# ## Adding a column with values

# %%
df1['New Added']= 45

# %% [markdown]
# ### this adds a new column to the last of the DataFrame

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### to add to a desired index we use:

# %%
df1.insert(2,'testId', 109)

# %%
df1
# Out:
#      PassengerId  Survived  testId  Pclass  \
# 0              1         0     109       3
# 1              2         1     109       1
# 2              3         1     109       3
# 3              4         1     109       1
# 4              5         0     109       3
# ..           ...       ...     ...     ...
# 886          887         0     109       2
# 887          888         1     109       1
# 888          889         0     109       3
# 889          890         1     109       1
# 890          891         0     109       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
d = {'col1':[1,2], 'col2':[3,4]}

# %%
fd = pd.DataFrame(d)

# %%
fd
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
fd.col1 = [100,200]

# %%
fd
# Out:
#    col1  col2
# 0   100     3
# 1   200     4

# %%
fd.col1
# Out:
# 0    100
# 1    200
# Name: col1, dtype: int64

# %%
fd.col1 = fd.col1 + 300

# %%
fd
# Out:
#    col1  col2
# 0   400     3
# 1   500     4

# %%
# for a dataset with price, this is just example

# %% [markdown]
# df.price # df['price']

# %%
df.price.mean()

# %%
df.price.median()
