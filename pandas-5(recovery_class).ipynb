# %%
import pandas as pd

# %%
df = pd.read_csv('ecommerce.csv')

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %% [markdown]
# ## Correlation  pd.DataFrame.corr()

# %%
df.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %% [markdown]
#  negative values shows no correlationship, more than 0.6 is good.
#  less than -0.6, negative correlation
#  more than +0.6, positive correlation

# %%
df.drop(['Avatar'], axis=1, inplace=True)

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address  Avg. Session Length  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            34.497268
# 1       4547 Archer Common\nDiazchester, CA 06566-8576            31.926272
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            33.000915
# 3     1414 David Throughway\nPort Jason, OH 22070-1220            34.305557
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...            33.330673
# ..                                                 ...                  ...
# ...

# %%
round(13.99992, 2)
# Out:
# 14.0

# %%
for index in df.index:
    df.loc[index, 'Avg. Session Length'] = round(df.loc[index, 'Avg. Session Length'],2)

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address  Avg. Session Length  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605                34.50
# 1       4547 Archer Common\nDiazchester, CA 06566-8576                31.93
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...                33.00
# 3     1414 David Throughway\nPort Jason, OH 22070-1220                34.31
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...                33.33
# ..                                                 ...                  ...
# ...

# %%
def round_2(s):
    return round(s,2)

# %%
df['Time on App'].apply(round_2)
# Out:
# 0      12.66
# 1      11.11
# 2      11.33
# 3      13.72
# 4      12.80
#        ...
# 495    13.57
# 496    11.70
# 497    11.50
# 498    12.39
# 499    12.42
# Name: Time on App, Length: 500, dtype: float64

# %%
df['Time on App']= df['Time on App'].apply(round_2)

# %%
df['Length of Membership']= df['Length of Membership'].apply(lambda x: round(x,2))

# %%
df['Time on Website']= df['Time on Website'].apply(lambda x: round(x,2))

# %%
df['Yearly Amount Spent']= df['Yearly Amount Spent'].apply(lambda x: round(x,2))

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address  Avg. Session Length  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605                34.50
# 1       4547 Archer Common\nDiazchester, CA 06566-8576                31.93
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...                33.00
# 3     1414 David Throughway\nPort Jason, OH 22070-1220                34.31
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...                33.33
# ..                                                 ...                  ...
# ...

# %% [markdown]
# ##  df.groupby()

# %%
dff = pd.read_csv('titanic_test.csv')

# %%
dff = dff.groupby('Sex')

# %%
dff.get_group('male')
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
dff= pd.read_csv('titanic_test.csv')

# %%
dff.sort_values(['Name','Age'])  # if name not found sort by age
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # concatenate

# %%
dff.Sex.isnull().sum()
# Out:
# 0

# %%
def convert_gender(g):
    if g.lower == 'male':
        return 1
    elif g.lower == 'female':
        return 0
    else:
        pd.NA

# %%
def convert_gender(g):
    if g == pd.NA or g == np.NA or g == None or g== '':
        pd.NA
    else:
        if g.lower == 'male':
            return 1
        elif g.lower == 'female':
            return 0

# %%
dff.Sex = dff.Sex.apply(convert_gender)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 dff.Sex = dff.Sex.apply(convert_gender)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# ...

# %% [markdown]
# concatenate:

# %%
dff = pd.read_csv('titanic_test.csv')

# %%
male = dff.drop('Sex', axis=1)

# %%
male = dff[['Sex']]

# %%
dff.drop('Sex', axis=1, inplace=True)

# %%
pd.concat([dff, male], axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...
