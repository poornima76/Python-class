# %% [markdown]
# # To find rows in a DataFrame we use iloc and loc

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic_test.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %% [markdown]
# ## if there is a key then we must use the key in loc but here there is no labels

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[[0]]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # Data Filtering

# %%
df[df.Age>20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Survived == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Survived == 1].Survived.count()
# Out:
# 342

# %%
df[df.Sex == 'male'].shape
# Out:
# (577, 12)

# %%
df[df.Sex == 'female'].shape
# Out:
# (314, 12)

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## EDA is done because:
# #### Data Acquisition
# #### Data isn't always clean, in raw format

# %%
df[(df.Sex == 'male') & (df.Age > 20)]
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 0              1         0       3        Braund, Mr. Owen Harris  male  22.0
# 4              5         0       3       Allen, Mr. William Henry  male  35.0
# 6              7         0       1        McCarthy, Mr. Timothy J  male  54.0
# 13            14         0       3    Andersson, Mr. Anders Johan  male  39.0
# 20            21         0       2           Fynney, Mr. Joseph J  male  35.0
# ..           ...       ...     ...                            ...   ...   ...
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 884          885         0       3         Sutehall, Mr. Henry Jr  male  25.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
# 889          890         1       1          Behr, Mr. Karl Howell  male  26.0
# 890          891         0       3            Dooley, Mr. Patrick  male  32.0
#
# ...

# %% [markdown]
# ## Data Wrangling or Munging

# %% [markdown]
# #### 1. Discovering
# #### 2. Structuring
# #### 3. Cleaning
# #### 4. Enriching
# #### 5. Validating
# #### 6. Publishing

# %% [markdown]
# Here the EDA analysis is done by first we find male with age greater than 20 and then the age is taken out which comes in a pandas Series format

# %% [markdown]
# Then the Series format has a count() method so we use acess the Age then count the number of male with age above 20

# %%
df[(df.Sex == 'male') & (df.Age > 20)].Age.count()
# Out:
# 351

# %% [markdown]
# EDA is done: graph plotting and seeing the nature of data so that we can choose the right machine learning model

# %% [markdown]
# We represent the data in pie chart, bar graph, histogram

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan, 'Qv'], dtype=object)

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df.Age < 1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
df.Survived.dtype
# Out:
# dtype('int64')

# %%
df.Survived.max()
# Out:
# 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# memory usage: 83.7+ KB is this but after we convert the dtype of Survived we get

# %%
df.Survived = df.Survived.astype('int8')

# %%
df.Survived.dtype
# Out:
# dtype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int8
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), int8(1), object(5)
# memory usage: 77.6+ KB

# %% [markdown]
# the memory usages is memory usage: 77.6+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.PassengerId.dtype
# Out:
# dtype('int64')

# %%
df.PassengerId = df.PassengerId.astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int8
#  1   Survived     891 non-null    int8
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), int8(2), object(5)
# memory usage: 71.5+ KB

# %% [markdown]
# memory usage: 71.5+ KB

# %%
df.Pclass.max()
# Out:
# 3

# %%
 df.SibSp.max()
# Out:
# 8

# %%
df.SibSp.astype('int8').info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: SibSp
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int8
# dtypes: int8(1)
# memory usage: 1019.0 bytes

# %%
df.Parch = df.Parch.astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int8
#  1   Survived     891 non-null    int8
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int8
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(2), int8(3), object(5)
# memory usage: 65.4+ KB

# %%
import numpy as np

# %%
df[(df.Embarked == 'S') | (df.Embarked == 'C')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          117         0       3
# 886          119         0       2
# 887          120         1       1
# 888          121         0       3
# 889          122         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df.Embarked == 'S') | (df.Embarked == 'C')].Embarked.count()
# Out:
# 812

# %% [markdown]
# isin() is used as a alternative for | (or)

# %%
df[df.Embarked.isin(['S','C'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          117         0       3
# 886          119         0       2
# 887          120         1       1
# 888          121         0       3
# 889          122         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Embarked.isin(['S','C'])].Embarked.count()
# Out:
# 812

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
df[df.Survived == 1].count()
# Out:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# dtype: int64

# %%
df.Name.dtype
# Out:
# dtype('O')

# %%
df.Name.str.contains('Dr').sum()
# Out:
# 11

# %%
df[df.Name.str.contains('Dr.')]
# Out:
#      PassengerId  Survived  Pclass  \
# 47            48         1       3
# 130         -125         0       3
# 245          -10         0       1
# 317           62         0       2
# 398         -113         0       2
# 416          -95         1       2
# 632          121         1       1
# 660         -107         1       1
# 679          -88         1       1
# 766           -1         0       1
# 796           29         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 47                         O'Driscoll, Miss. Bridget  female   NaN      0
# 130                             Drazenoic, Mr. Jozef    male  33.0      0
# 245                      Minahan, Dr. William Edward    male  44.0      2
# 317                             Moraweck, Dr. Ernest    male  54.0      0
# 398                                 Pain, Dr. Alfred    male  23.0      0
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
# ...
