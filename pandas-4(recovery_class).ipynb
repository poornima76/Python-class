# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. data in wrong format
# 2. missing datas
# 3. outliers
# 4. duplicates

# %% [markdown]
# if value is categorical we use mode

# %% [markdown]
# remove column if there is many null data, because it is insignificant

# %% [markdown]
# #### pd.DataFrame.drop()

# %% [markdown]
# #### this is used to drop a column

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic_test.csv')

# %% [markdown]
# ### drop() does not modify the real df so when df is printed, there is PassengerId

# %%
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### if we put inplace=True then the real df is also changed so PassengerId is deleted from df

# %%
df.drop('PassengerId', axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(['Survived', 'Pclass'], axis=1,inplace=True)

# %%
df
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df = pd.read_csv('titanic_test.csv')

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## dropna()
# #### dont drop the needed values, always be careful

# %%
df = pd.read_csv('titanic_test.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Feature Engineering : reduces the number of inputs

# %% [markdown]
# ### to drop a row we use dropna()
# #### like pd.NA, np.NAN and all

# %% [markdown]
# ## Univariate Analysis: there is only one variable.

# %% [markdown]
# ## PCA Principal Component Analysis: It is a dimensional reduction technique

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### this drops all the values so the data is lost for Cabin and Age, we still need the Age so we use subset.

# %%
df.dropna(subset=['Age'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %% [markdown]
# ### Here the na values are deleted for Age so we get that from df.info()

# %%
df = pd.read_csv('titanic_test.csv')

# %%
df.Age.fillna(df.Age.mean(), inplace=True)

# %% [markdown]
# df['Date']= pd.to_datetime(df['Date']) for date

# %%
df.Age.loc[0]
# Out:
# 22.0

# %%
df.loc[0, 'Age'] = 105

# %%
for index in df.index:
    print(df.loc[index, 'Age'])
# Out:
# 105.0
# 38.0
# 26.0
# 35.0
# 35.0
# 29.69911764705882
# 54.0
# 2.0
# 27.0
# 14.0
# 4.0
# 58.0
# 20.0
# 39.0
# 14.0
# 55.0
# 2.0
# 29.69911764705882
# 31.0
# 29.69911764705882
# 35.0
# 34.0
# 15.0
# 28.0
# 8.0
# 38.0
# 29.69911764705882
# 19.0
# 29.69911764705882
# 29.69911764705882
# 40.0
# 29.69911764705882
# 29.69911764705882
# 66.0
# 28.0
# 42.0
# 29.69911764705882
# 21.0
# 18.0
# 14.0
# 40.0
# 27.0
# 29.69911764705882
# 3.0
# 19.0
# 29.69911764705882
# 29.69911764705882
# 29.69911764705882
# 29.69911764705882
# 18.0
# 7.0
# 21.0
# 49.0
# 29.0
# 65.0
# 29.69911764705882
# 21.0
# 28.5
# 5.0
# 11.0
# 22.0
# 38.0
# 45.0
# 4.0
# 29.69911764705882
# 29.69911764705882
# 29.0
# 19.0
# 17.0
# 26.0
# 32.0
# 16.0
# 21.0
# 26.0
# 32.0
# 25.0
# 29.69911764705882
# 29.69911764705882
# 0.83
# 30.0
# 22.0
# 29.0
# 29.69911764705882
# 28.0
# 17.0
# 33.0
# 16.0
# 29.69911764705882
# 23.0
# 24.0
# 29.0
# 20.0
# 46.0
# 26.0
# 59.0
# 29.69911764705882
# 71.0
# 23.0
# 34.0
# 34.0
# 28.0
# ...

# %%
for index in df.index:
    if df.loc[index, 'Age'] > 90:
        df.loc[index, 'Age'] = 90

# %%
df.Age.max()
# Out:
# 90.0

# %% [markdown]
# ### since Age cannot be 105 so we cleaned the data by replacing all the bad value which is greater than 90 to 90.

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan, 'Qv'], dtype=object)

# %%
df.Embarked.isnull().sum()
# Out:
# 2

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.Embarked.fillna(df.Embarked.mode(), inplace=True)

# %% [markdown]
# ## how many people from a location

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [markdown]
# ## how many people get on boat from the max people location

# %%
df[df.Embarked == df.Embarked.mode().iloc[0]].Embarked.count()
# Out:
# 644
